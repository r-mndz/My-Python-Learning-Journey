# %% [markdown]
# <a href="https://colab.research.google.com/github/r-mndz/My-Python-Learning-Journey/blob/main/CS50_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CS50_Python_Functions_String str

# %%
# ========================================================
# Below is the .str() built in Types String Methods
# .strip() remove white space
# .capitalize() Capitalize user's name
# .title() title case user's name
# .split() split a string into multiple smaller substring

# ========================================================
# below is printing using the f string or format string technique
# Ask user for their name

name = input("What is your name? ").strip().title() # ask input from user
firstname, lastname = name.split(" ")
print("below is the output using the f string or format string") # just an fyi below
print(f"hello, {lastname}")
print(f"hello, {firstname}")
print(f"hello,{name}")

# ========================================================

# %% [markdown]
# Integer, Float, Round

# %%
# Calculator ( needs improvement ( handling error, making sure user only input numbers))
# float with decime
# int whole number
# round roundoff (number[,ndigits]) square bracket in the documentation means optional

num1 = float(input("Enter first number: ")) #---> this convert str to int
num2 = float(input("Enter second number: ")) #---> this convert str to int
calculate = round(num1+num2)
print(f"{calculate: ,}") # the : will provide comma separtor for every three digits example 1,000 or 1,000,000

#============> below is division <=========
x = float(input("What's x? "))
y = float(input("What's y? "))
z = round(x / y, 2)
print(z)
# z = x / y  this is another printing without using the Round method
# print(f"{z:.2F}") this is another printing without using the Round method
# Out:
# Enter first number: 1
# Enter second number: 2
#  3
# What's x? 2
# What's y? 4
# 0.5

# %% [markdown]
# #Function

# %%
def hello(to="world"):  #------ this line is to define your function name hello()
    print("hello,", to) #------ same goes with this line is to define your function name hello()
    #----> defining function so that you do not need to repeat yourself again and again
#------------------------------------------------------------------------------------------#
hello() # ---> calling function with no arguments
name = input("What's your name?")
hello(name) #---> calling hello() function and passing parameters name input
# Out:
# hello, world
# What's your name?David
# hello, David

# %% [markdown]
# Creating function

# %%
def main():
    name = input("What's your name? ")
    hello(name)

def hello(to):
    print("hello, ",to)

main()
# Out:
# What's your name? David
# hello,  David

# %% [markdown]
# Calculator

# %%
# ---> solve a simple math problme, use the return
def main():
    x = int(input("What's X? "))
    print("X squared is", square(x))

def square(n):
    return n * n # ---> this mean raise the number to the power of 2, can be n ** 2 or n * n


main()
# Out:
# What's X? 5
# X squared is 25

# %% [markdown]
# #Conditionals - Compare

# %%
x = int(input("What's x? "))
y = int(input("What's y? "))


# if x < y:
#   print("x is less than y")

# elif x > y:
#   print("x is greater than y")

# elif x == y:
#   print("x is equal to y")

# else:
#   print("x is equal to y")

# if x < y or x > y:
#    print("x is not equal to y")
# else:
#    print("x is equal to y")

# if x != y:
#    print("x is not equal to y")
# else:
#    print("x is equal to y")

if x == y:
   print("x is equal to y")
else:
   print("x is not equal to y")

# %% [markdown]
# Grade check user score

# %%
score = int(input("Score:"))

if score >= 90:
   print("Grade: A")
elif score >= 80:
     print("Grade: B")
elif score >= 70:
     print("Grade: C")
elif score >= 60:
     print("Grade: D")
else:
    print("Grade: F")

# %% [markdown]
# Parity check if it is odd or even

# %%
# modulu operator - how much is left over after dividing one number by another


# if x % 2 == 0:
#     print("Even")
# else:
#     print("Odd")

def main():
    x = int(input("What's x? "))
    if is_even(x):
        print("Even")
    else:
        print("Odd")

def is_even(n):
    return n % 2 == 0

main()
# Out:
# What's x? 2
# Even

# %% [markdown]
# Match keyword

# %%
# ---> program that will match the input based on the list

name = input("What's your name? ")

# if name == "Harry":
#     print("Gryffindor")
# elif name == "Hermione":
#     print("Gryffindor")
# elif name == "Ron":
#     print("Gryffindor")
# elif name == "Draco":
#     print("Slytherin")
# else:
#     print("Who?")

match name:
    case "Harry" | "Hermione" | "Ron" :
      print("Gryffindor")
    case "Draco":
      print("Slytherin")
    case _:
      print("Who?")
# Out:
# What's your name? Harry
# Gryffindor

# %% [markdown]
# Recommendation - IF ELSE

# %%
# ---> this program will recommend game based on the user input, using function and if else
def main():
    difficulty = input("Difficulty or Casaul? ")
    player = input("Multiplayer or Single-player? ")

    if difficulty == "Difficult":
        if player == "Multiplayer":
           recommend("Poker")

        elif player == "Single-player":
              recommend("Klondike")

        else:
            print("Enter a valid difficulty")


    elif difficulty == "Casual":

        if player == "Multiplayer":
            recommend("Hearts")
        elif player == "Single-player":
            recommend("Clock")

    else:
      print("Enter a valid difficulty")

def recommend(game):
    print("You might like", game)

main()

# %% [markdown]
# Boolean Expression

# %%
# ---> this program will recommend game based on the user input, using function and if else and boolean
def main():
    difficulty = input("Difficulty or Casual? ")
    if not (difficulty =="Difficult" or difficulty =="Casual"):
       print("Enter a valid difficulty")
       return

    player = input("Multiplayer or Single-player? ")
    if not (player =="Multiplayer" or player =="Single-player"):
       print("Enter a valid number of players")
       return

    if difficulty == "Difficult" and player == "Multiplayer":
         recommend("Poker")

    elif difficulty == "Difficult" and player == "Single-player":
          recommend("Klondike")

    elif difficulty == "Casual" and player == "Multiplayer":
          recommend("Hearts")
    else:
          recommend("Clock")


def recommend(game):
    print("You might like", game)

main()
# Out:
# Difficulty or Casual? Casual
# Multiplayer or Single-player? Single-player
# You might like Clock

# %% [markdown]
# # Loops

# %%
# ---->  my introduction to learning loops < ---#

# ---> while loop
i = 0   # ---> initial value
x = int(input("What's the number of iteration? ")) # ---> number of counter
while i < x:  # ---> logic where check if i is less than x
      print("meow")  # ---> preferred output
      i += 1   # ---> increment 1

# %%
# ---> for loop - list another type of data, a list of things
# --> for loop it allows you to iterate over a list of items.
# --> Range is a function
5

# while True:  # ---> infinite loop
#    n = int(input("What's n?"))
#    if n > 0 : # ---> check user input not negative
#        break
# for _ in range(n):
#     print("meow")


def main(): # ---> our main function where you call the get number and pass it on the meow function
    number = get_number()
    meow(number)

def get_number():  # ---> function to get input from user
    while True:
      n = int(input("What's n? "))
      if n > 0:
        break
    return n

def meow(n):   # ---> function to go thru the list of number provided by the user : using for loop and Range function
    for _ in range(n):
        print("meow")

main()

# %%
# ---> LIST
# ---> what is list ? a list of item
# ---> using square bracket seperated by comma
# ---> how to print a content in a list? Answer: short answer is get the index, how use the variable name [the index]
# ---> List : count start from 0

students = ["Hermione", "Harry", "Ron"]

for i in range((len(students))):   # ---> return a range of value, use the len() function to pass the lengt of values
     print(i + 1, students[i])     # --->

# %%
# ---> Dictionary {dict} another type of Data
# ---> Dictionary {dict} a data structure allows you to associate one value with another
# ---> use curly braces {}

# ---> looping over the dictionary using for loop

students = {
           "Hermione": "Gryffindor",
           "Harry": "Gryffindor",
           "Ron": "Gryffindor",
           "Draco": "Slytherin"
}

for student in students:   #---. in Python to iterate over a dictionary, by design, it iterates over all of the keys.
  print(student, students[student], sep =" --->  ")
# Out:
# Hermione
# Harry
# Ron
# Draco

# %%
# ---> this program is an example of combination of List and dictionary
# ---? here we were create a List of dictionaries

students = [
    {"name": "Hermione", "house": "Gryffindor", "patronus": "Otter"},
    {"name": "Harry", "house": "Gryffindor", "patronus": "Stag"},
    {"name": "Ron", "house": "Gryffindor", "patronus": "Jack Russell terrier"},
    {"name": "Draco", "house": "Slytherin", "patronus": None}
]

for student in students:
  print(student["name"],student["house"],student["patronus"],sep= ": ")
# Out:
# Hermione: Gryffindor: Otter
# Harry: Gryffindor: Stag
# Ron: Gryffindor: Jack Russell terrier
# Draco: Slytherin: None

# %%
# ---> this line of code have the same output
# ---> but I uses two different loops

# x= int(input("What's n?"))
# i=0
# while i< x:
#   print("#")
#   i +=1

x= int(input("What's n?"))

for i in range(x):
  print("#")
# Out:
# What's n?3
# #
# #
# #

# %%
# ---> in this code I write a function that get the user input then pass it to another function that will run a loop
# --->  cont - a loop that will check the range depending on the value that the user input
def main():
  print_barrier_height(get_height_input())

def print_barrier_height(a):
  for i in range(a):
    print("#")

def get_height_input():
  n = int(input("What's the barrier height?"))
  return n
main()
# Out:
# What's the barrier height?5
# #
# #
# #
# #
# #

# %% [markdown]
# # Excercise

# %%
# ---> this program will find factor of the number

# TODO---> I need to create a program that will get the factor of a number
# 1. testing of divisibility
# > if a number is divisible by another it means it is a factor
# this is still pending not sure how to solve i will come back to this

# # n = int(input("what's n? "))
# #

# # n = int(input("what's n? "))

# # def main():
# #     factor = get_input()
# #     show_factor()

# # # def check_factor(i):
# # #     x = 0
# # #     while x < n :
# # #      x += 1
# # #     return x

# # def get_input():   # ---? get input
# #      number = int(input("What's n? "))
# #      while True:
# #        if number > 0 :
# #            break
# #      return number

# # def show_factor(number):
# #      x = 0
# #      while x < number :
# #       x +=1
# #       if number % x == 0:  # ---? this is the formul to get the factor of a number, user input will be divided by the number x and if no ramainder it means the number is factors
# #          print(x,f"is the factor of {number}")  # ---> this will print the factors based on the above condition.

# def main():
#     input = get_input()
#     my_list = show_factor(input)
#     get_list(my_list)
#     # for i in range(len(my_list)):
#     #   get_list = i + 1


# def get_input():
#     while True:
#      number = int(input("What's n?"))
#      if number > 0 :
#          break
#     return number

# def show_factor(any):
#     x = 0
#     while x < any :
#       x +=1
#       if any % x == 0 :
#          my_list = [x]



# def get_list(z):
#     for i in range(len(show) ):
#         my_lists = i + 1
#     return my_lists
#     print(f"These are the factor of number: {input}", get_list)

# main()

def main():

    check_factor(get_input())
    # print_factor(check_factor(number))
    # print(check_factor())


def get_input():
    while True:
      number = int(input("What's n?"))
      if number > 0:
       print(f"These are the factor of number: {number}")
       break
    return number


def check_factor(n):
     x = 0
     while x < n :
      x += 1
      if n % x == 0 :
         print(x, end="  ")
        # myfactor_list = [x]
        # for i in range (len(myfactor_list)):
        #     print(myfactor_list[i])




# def print_factor(z):
#     if z % x == 0:
#       factor_list = [x]
#     return factor_list

main()
# Out:
# What's n?24
# These are the factor of number: 24
# 1  2  3  4  6  8  12  24

# %%
# ---> Google search tool using Python
# In this program I will create an application that will use the Google search module and query based on the user input
# pending -- no results found
from googlesearch import search  #---> import module

print("Welcome to my Google search tool!")
query = input("What's on your mind? : ") # ---> Taking query from user
sucess = False
for i in search(query, start=0, stop=5):
    print(i)
# Out:
# Welcome to my Google search tool!
# What's on your mind? : Coding

# %%
# -- this program generate random number
import random  # ---> this import the random module

print("Welcome to Rolling Dice Simulator")

choice = input("Want to roll the dice? (Y?N)")  # --- asking user input
if choice == "Y" or choice == "y":

    while choice == "y" or choice == "Y":
      random_num = random.randint(1,6)   #---> this line generate a random int between 1 - 6
      if random_num == 1 :
       print("======")
       print("|  @ |")
       print("======")

      elif random_num == 2 :
       print("======")
       print("| @@ |")
       print("======")

      elif random_num == 3 :
       print("======")
       print("| @@ |")
       print("| @  |")
       print("======")

      elif random_num == 4 :
       print("======")
       print("| @@ |")
       print("| @@ |")
       print("======")

      elif random_num == 5 :
       print("======")
       print("| @@ |")
       print("| @  |")
       print("| @@ |")
       print("======")

      else:
        print("======")
        print("| @@ |")
        print("| @@ |")
        print("| @@ |")
        print("======")

      choice = input("Want to roll the dice? (Y?N)") # ---> this is your counter to check the loop if it still TRUE

      if choice == "N" or choice == "n":
        print("\n\tThank you for playing")

elif choice =="N" or choice == "n":
  print("\tThank you for playing")
else:
    print("Sorry I don't understand")
# Out:
# Welcome to Rolling Dice Simulator
# Want to roll the dice? (Y?N)n
# 	Thank you for playing

# %%
import datetime
#name = input("what is your name? ")
#birth_year = int(input("What is you birth year? "))
#age = 2025- birth_year
# print("Hello",name)
# print("Age:",age)
#--------------------------------------

#Create a program that will ask the user to input name and birth year and then calculate the age
# Solve this by creating your function
def get_date(y):
    year = y.year
    return year  #----> capture the year value to return value

def calc_age(get_age):
    age = get_date - get_age
    print("Age: ", age)

name = input("what is your name? ")
birth_year = int(input("What is you birth year? "))
year_now = datetime.datetime.now()
get_date = get_date(year_now)
calc_age(birth_year)
# Out:
# what is your name? david
# What is you birth year? 1995
# Age:  30

# %% [markdown]
# Identify if it's a prime number

# %%
#---> this program identify wether the user input a prime number or not.
def is_prime(n):
    if n <= 1:
      return False
    if n == 2:
      return True
    if n % 2 == 0:
      return False
    for i in range(3, int(n**0.5) + 1, 2):
      if n % i == 0:
        return False
    return True
n = int(input("Enter a number: "))
print(f"{n} is a prime:", is_prime(n))
# Out:
# Enter a number: 5
# 5 is a prime: True

# %% [markdown]
# Create Function

# %%
# ---> this program will capture year, month, date
import datetime

def get_date(y):
    year = y.year
    month = y.month
    day = y.day
    print(year)
    print(month)
    print(day)

date_now = datetime.datetime.now()
get_date(date_now)
# Out:
# 2025
# 11
# 26

# %%
def compute():
    total_amount = qty * price_per_unit
    print("You buy a",item1,", And your Total amount to pay is:", total_amount)


item1 = input("Item name: ")
price_per_unit = int(input("Price per piece: ")) # convert str to int
qty = int(input("How many QTY? "))
compute()
# Out:
# Item name: Strawberry
# Price per piece: 50
# How many QTY? 100
# You buy a Strawberry , And your Total amount to pay is: 5000

# %% [markdown]
# IF else

# %%
# ---> this program will check wheter the hard coded string is true or false using the if else statemet and return
def greet(input):
    if "hello" in input:
      return "hello, there"
    else:
      return "I'm not sure what you mean"

print(greet("hello computer"))
# Out:
# hello, there

# %% [markdown]
# function - side effect

# %%
emoticon = "v.v"

def main():
    global emoticon
    say("Is anyone there?")
    emoticon = ":D"
    say("Oh, hi!")

def say(phrase):
    print(phrase +" " + emoticon)

main()
# Out:
# Is anyone there? v.v
# Oh, hi! :D

# %% [markdown]
# String method

# %%
# ---> this program cleaned user input remove spaces and capitalize properly
# ---> .strip() remove white space
# --->  .append(), to connect the new list to a new declared list
# --->  .title() to properly capitalized list of stripe
# --->  .join() to join list
SHOWS = [
    " Avatar: the last airbender",
    "Ben 10",
    "Athur",
    " Spongebob Squarepants",
    "Phineas and ferb",
    "Kim possible",
    "Jimmy Neutron ",
    "the Proud family"
]

def main():
    cleaned_shows = []   # ---> here I created a new list to of cleaned data
    for show in SHOWS:
        cleaned_shows.append((show.strip().title()))  # ---> here I use the .append method to capture the cleaned data
    print(', '.join(cleaned_shows))  #---> here is where I print the new list from cleaned data.

main()
# Out:
# Avatar: The Last Airbender, Ben 10, Athur, Spongebob Squarepants, Phineas And Ferb, Kim Possible, Jimmy Neutron, The Proud Family
